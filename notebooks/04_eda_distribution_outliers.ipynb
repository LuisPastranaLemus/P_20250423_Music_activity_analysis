# %% [markdown]
# #### Data set feature engineering
#
# Dataset:
#
#  - _music_clean.csv_
#  - _music_location.csv_
#  - _music_location_datetime_.csv
#
# Author: Luis Sergio Pastrana Lemus
# Date: 2025-04-23

# %% [markdown]
# # Dataset Shape and Dispersion

# %% [markdown]
# ## __1. Libraries__

# %%
from IPython.display import display, HTML
import os
import pandas as pd
from pathlib import Path
import sys

# Define project root dynamically, gets the current directory from whick the notebook belongs and moves one level upper
project_root = Path.cwd().parent

# Add src to sys.path if it is not already
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# Import function directly (more controlled than import *)
from src import *

# %% [markdown]
# ## __2. Path to Data file__

# %%
# Build route to data file and upload
data_file_path = project_root / "data" / "processed"
df_music_clean = load_dataset_from_csv(data_file_path, "music_clean.csv", sep=',', header='infer')
df_music_location = load_dataset_from_csv(data_file_path, "music_location.csv", sep=',', header='infer')
df_music_loc_dt = load_dataset_from_csv(data_file_path, "music_location_datetime.csv", sep=',', header='infer')

# %%
# Format notebook output
format_notebook()

# %% [markdown]
# ## __3. Casting to data types__

# %% [markdown]
# ### **3.0** Casting Data Types

# %% [markdown]
# #### **3.0.1** Casting to category datatype

# %%
# Casting to category dtype 
df_music_clean = cast_datatypes(df_music_clean, 'category', c_include=['genre'])
df_music_clean = cast_datatypes(df_music_clean, 'category', c_include=['city'])
df_music_clean = cast_datatypes(df_music_clean, 'category', c_include=['day'])

# %% [markdown]
# #### **3.0.2** Casting to datetime data type

# %%
# Casting to datetime dtype 
df_music_clean = cast_datatypes(df_music_clean, 'datetime', date_format="%H:%M:%S", c_include=['time'])

# %%
df_music_clean
# Out:
#          userid                           track            artist       genre         city      time        day
# 0      FFB692EC               kamigata_to_boots  the_mass_missile        rock  shelbyville  20:28:33  wednesday
# 1      55204538     delayed_because_of_accident  andreas_ronnberg        rock  springfield  14:07:09     friday
# 2        20EC38               funiculi_funicula       mario_lanza         pop  shelbyville  20:58:07  wednesday
# 3      A3DD03C9           dragons_in_the_sunset          fire_ice        folk  shelbyville  08:37:09     monday
# 4      E2DC1FAE                     soul_people        space_echo       dance  springfield  08:34:34     monday
# ...         ...                             ...               ...         ...          ...       ...        ...
# 59957  729CBB09                         my_name            mclean         rnb  springfield  13:32:28  wednesday
# 59958  D08D4A55  maybe_one_day_feat_black_spade         blu_exile      hiphop  shelbyville  10:00:00     monday
# 59959  C5E3A0D5                       jalopiina           unknown  industrial  springfield  20:09:26     friday
# 59960  321D0506                   freight_train     chas_mcdevitt        rock  springfield  21:43:59     friday
# 59961  3A64EF84       tell_me_sweet_little_lies      monica_lopez     country  springfield  21:59:46     friday
#
# [59962 rows x 7 columns]

# %%
df_music_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59962 entries, 0 to 59961
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userid  59962 non-null  object
#  1   track   59962 non-null  object
#  2   artist  59962 non-null  object
#  3   genre   59962 non-null  category
#  4   city    59962 non-null  category
#  5   time    59962 non-null  object
#  6   day     59962 non-null  category
# dtypes: category(3), object(4)
# memory usage: 2.1+ MB

# %%
type(df_music_clean['time'].iloc[0])
# Out:
# datetime.time

# %% [markdown]
# ## __4. Distribution and Outliers__

# %%
# df_music_clean.columns

# evaluate_central_trend(df, column)

# outlier_limit_bounds(df, column, bound='both', clamp_zero=False)

# evaluate_correlation(df, columns=None)

# %%
plotly_frequency_density_numeric_plotlypx(df_music_location['tracks'], bins=50, density=False, color='grey', title='Global Tracks Distribution', xlabel='Tracks', ylabel='Frequency/Density',
                                          xticks_range=(0, 50, 1), rotation=0, show_kde=False)

# %%
plotly_frequency_density_numeric_plotlypx(df_music_location['artists'], bins=40, density=False, color='grey', title='Global Artists Distribution', xlabel='Artists', ylabel='Frequency/Density',
                                          xticks_range=(0, 40, 1), rotation=0, show_kde=False)

# %%
plotly_frequency_density_numeric_plotlypx(df_music_location['genres'], bins=18, density=False, color='grey', title='Global Genres Distribution', xlabel='Genres', ylabel='Frequency/Density',
                                          xticks_range=(0, 18, 1), rotation=0, show_kde=False)

# %%
plotly_frequency_density_numeric_plotlypx(df_music_loc_dt['day'], bins=7, density=False, color='grey', title='Global Tracks Distribution By Day', xlabel='Days', ylabel='Frequency/Density',
                                          xticks_range=(1,7,1), rotation=0, show_kde=False)

# %%
plotly_frequency_density_numeric_plotlypx(df_music_loc_dt['hour'], bins=24, density=False, color='grey', title='Global Tracks Distribution By Hour', xlabel='Hours', ylabel='Frequency/Density',
                                          xticks_range=(0, 24, 1), rotation=0, show_kde=False)

# %% [markdown]
# ### **4.2** Outliers evaluation

# %% [markdown]
# #### **4.2.1** Outliers

# %%
outlier_limit_bounds(df_music_location, 'tracks', bound='both', clamp_zero=True, verbose=True)
# Out:
# > <b>Warning:</b> IQR = 0 for '<i>tracks</i>' (Q1 (1.0) = Q3 (1.0)).<br>Using fallback thresholds mean ± 2*std.
# > Mean = 1.425200, Std = 1.208311<br>> Lower = <b>0.000000</b>, Upper = <b>3.841821</b>
# > Found <b>1612</b> outlier(s) using fallback method.
#               city    userid  tracks  artists  genres
# 4      shelbyville  10189D10       4        3       2
# 11     shelbyville  102A0499       5        5       4
# 15     shelbyville  1049FBE1       7        6       6
# 16     shelbyville  104B7BA5       4        4       2
# 115    shelbyville  12329DEF       6        6       2
# ...            ...       ...     ...      ...     ...
# 41277  springfield  FF710BD9      11       11       5
# 41286  springfield  FF8287BB      17       17       4
# 41309  springfield  FFBE3E18       8        8       2
# 41321  springfield  FFD1A16F       6        6       2
# 41348  springfield   FFFBB52       4        4       4
#
# [1612 rows x 5 columns]

# %%
outlier_limit_bounds(df_music_location, 'artists', bound='both', clamp_zero=True, verbose=True)
# Out:
# > <b>Warning:</b> IQR = 0 for '<i>artists</i>' (Q1 (1.0) = Q3 (1.0)).<br>Using fallback thresholds mean ± 2*std.
# > Mean = 1.420653, Std = 1.202362<br>> Lower = <b>0.000000</b>, Upper = <b>3.825376</b>
# > Found <b>1596</b> outlier(s) using fallback method.
#               city    userid  tracks  artists  genres
# 11     shelbyville  102A0499       5        5       4
# 15     shelbyville  1049FBE1       7        6       6
# 16     shelbyville  104B7BA5       4        4       2
# 115    shelbyville  12329DEF       6        6       2
# 217    shelbyville  13EF647B       4        4       3
# ...            ...       ...     ...      ...     ...
# 41277  springfield  FF710BD9      11       11       5
# 41286  springfield  FF8287BB      17       17       4
# 41309  springfield  FFBE3E18       8        8       2
# 41321  springfield  FFD1A16F       6        6       2
# 41348  springfield   FFFBB52       4        4       4
#
# [1596 rows x 5 columns]

# %%
outlier_limit_bounds(df_music_location, 'genres', bound='both', clamp_zero=True, verbose=True)
# Out:
# > <b>Warning:</b> IQR = 0 for '<i>genres</i>' (Q1 (1.0) = Q3 (1.0)).<br>Using fallback thresholds mean ± 2*std.
# > Mean = 1.272310, Std = 0.708461<br>> Lower = <b>0.000000</b>, Upper = <b>2.689233</b>
# > Found <b>2129</b> outlier(s) using fallback method.
#               city    userid  tracks  artists  genres
# 11     shelbyville  102A0499       5        5       4
# 15     shelbyville  1049FBE1       7        6       6
# 92     shelbyville  11D3698F       3        3       3
# 217    shelbyville  13EF647B       4        4       3
# 230    shelbyville  1442051A       4        4       3
# ...            ...       ...     ...      ...     ...
# 41277  springfield  FF710BD9      11       11       5
# 41286  springfield  FF8287BB      17       17       4
# 41295  springfield   FF9C157       3        3       3
# 41312  springfield  FFC96562       3        3       3
# 41348  springfield   FFFBB52       4        4       4
#
# [2129 rows x 5 columns]

# %%
outlier_limit_bounds(df_music_loc_dt, 'day', bound='both', clamp_zero=True, verbose=False)
# Out:
# > <b>IQR-based thresholds for '<i>day</i>':</b><br>Q1 = 1.000000, Q3 = 5.000000, IQR = 4.000000<br>Lower = <b>0.000000</b>, Upper = <b>11.000000</b>

# %%
outlier_limit_bounds(df_music_loc_dt, 'hour', bound='both', clamp_zero=True, verbose=False)
# Out:
# > <b>IQR-based thresholds for '<i>hour</i>':</b><br>Q1 = 9.000000, Q3 = 20.000000, IQR = 11.000000<br>Lower = <b>0.000000</b>, Upper = <b>36.500000</b>

# %% [markdown]
# #### **4.2.2** Outliers and Data Dispersion Visualization

# %%
plot_horizontal_boxplot_plotlypx(df_music_location, 'tracks', title='Outliers and Data Dispersion for Tracks')

# %%
plot_horizontal_boxplot_plotlypx(df_music_location, 'artists', title='Outliers and Data Dispersion for Artists')

# %%
plot_horizontal_boxplot_plotlypx(df_music_location, 'genres', title='Outliers and Data Dispersion for Genres')

# %%
plot_horizontal_boxplot_plotlypx(df_music_loc_dt, 'day', title='Outliers and Data Dispersion for Days')

# %%
plot_horizontal_boxplot_plotlypx(df_music_loc_dt, 'hour', title='Outliers and Data Dispersion for Hours')
